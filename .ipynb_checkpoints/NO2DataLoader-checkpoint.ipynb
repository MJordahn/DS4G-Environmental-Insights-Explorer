# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import rasterio as rio
import folium
import cv2 as cv

# %%
lat=18.200178; lon=-66.064513
def overlay_image_on_puerto_rico(data, band_layer=2, cmap=lambda x: (1, 0, 0, x)):
    band = data
    m = folium.Map([lat, lon], zoom_start=9.45)
    folium.raster_layers.ImageOverlay(
        image=band,
        bounds = [[18.6,-67.3,],[17.9,-65.2]],
        colormap = cmap,
    ).add_to(m)
    return m

def readFile(name):
    image= rio.open(name)
    return(image)

def inpaintImg(im, setZero=False):
    row, col = im.shape
    avg_val = np.average(im)
    if setZero:
        im = im.clip(min=0)
        im = np.nan_to_num(x=im, nan=0)
    else:
        mask = np.ones((row+2,col+2))
        mask[1:-1,1:-1] = np.isnan(im)
        mask = np.uint8(mask)
        new_im = np.ones((row+2,col+2))*avg_val
        new_im[1:-1,1:-1] = im
        new_im = np.float32(new_im)
        new_im = np.float64(cv.inpaint(new_im, mask, 3, cv.INPAINT_NS)) # Inpaints using Navier-Stokes 
        new_im = new_im.clip(min=0) # sets negative values to zero
        im = new_im[1:-1,1:-1]
    return im #im

# %%
import pathlib
def dataLoader(folder):
    p = "./eie_data/"
    for path in pathlib.Path(p+folder+"/").iterdir():
        if path.is_file():
            image= rio.open(path)
            band2 = image.read(2)
            if np.sum(np.isnan(band2)) <= image.shape[0]*image.shape[1]*0.05:
                yield(image)
            
loader_s5p = dataLoader("s5p_no2")
#loader_gfs = dataLoader("gfs")
#loader_gldas = dataLoader("gldas")

# %% [markdown]
# We first calculate various statistics:

# %%
pic = readFile('./eie_data/s5p_no2/s5p_no2_20190504T165553_20190510T183608.tif')
pic.name.split("/")[-1][:-4]
# Out:
# 's5p_no2_20190504T165553_20190510T183608'

# %% [markdown]
# ## Test dataloader

# %%
loader_s5p = dataLoader("s5p_no2")

# %%
# Creates NA-map
#img = next(loader_s5p)
#img = readFile("eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180712T160623_20180719T105633.tif")
#img2 = readFile("eie_data\s5p_no2\s5p_no2_20180706T161914_20180712T200737.tif")
#img3 = readFile("eie_data\s5p_no2\s5p_no2_20181229T160630_20190104T181035.tif")
img4 = readFile("eie_data\s5p_no2\s5p_no2_20180716T163137_20180722T180949.tif")
#img5 = readFile("eie_data\s5p_no2\s5p_no2_20190424T164221_20190501T013253.tif")
#img6 = readFile("eie_data\s5p_no2\s5p_no2_20180927T165725_20181003T182739.tif")

print(img4.name)
im = img4.read(2)
lst = []
for i, item1 in enumerate(im):
    for j, item2 in enumerate(item1):
        if np.isnan(item2):
            lst.append([i,j])
lst = np.array(lst)
print("len list: ", len(lst))
print("NA Count: ", np.sum(np.isnan(im)))
# Out:
# eie_data\s5p_no2\s5p_no2_20190424T164221_20190501T013253.tif
# len list:  802
# NA Count:  802

# %%
if len(lst) > 0:
    plt.subplot(1, 2, 1)
    plt.scatter(lst[:,0], lst[:,1], s=0.5)

# %%
import matplotlib.cm as cm
import matplotlib.pylab as pl
from matplotlib.colors import ListedColormap

# %%
# Choose colormap
cmap = cm.get_cmap('Reds')
# Get the colormap colors
my_cmap = cmap(np.arange(cmap.N))
# Set alpha
my_cmap[:,-1] = np.linspace(0, 1, cmap.N)
# Create new colormap
my_cmap = ListedColormap(my_cmap)

# %%
mn = 0.0
mx = 6.750725398368169e-05
norm = matplotlib.colors.Normalize(vmin=mn, vmax=mx, clip=False)
cmap = cm.ScalarMappable(norm=norm, cmap=my_cmap)

# %%
t = inpaintImg(im, True)
print("min: ", np.min(t))
print("max: ", np.max(t))
overlay_image_on_puerto_rico(t, cmap=cmap.to_rgba)
# Out:
# 0.0
# 3.259242657804862e-05
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Clean Data

# %%
# Only 128 images does not contain NA-values in the second band.
# If we accept all pictures with less than 5% NA values we get 324 images.
# A total of 387 images are availible.

# %%
# Save names of all valid pictures in order:
loader_s5p = dataLoader("s5p_no2")
s5p_order = []
for img in loader_s5p:
    date = img.name.split("\\")[-1].split("_")[-2][:8]
    s5p_order.append([date, img.name])
# Date ordered:
s5p_order.sort(key=(lambda x: x[0]))   
# Number of valid pictures:
print("Number of availible images: ", len(s5p_order))
# Out:
# Number of availible images:  324

# %%
# Write images to new folder:
def writeCleanData(s5p_order):
    for i, [date, name] in enumerate(s5p_order):
        pic = readFile(name)
        new_dataset = rio.open(name.replace("s5p_no2", "cleaned_s5p_no2"),
                               "w",
                               driver=pic.meta['driver'],
                               dtype=pic.meta['dtype'],
                               height=pic.meta['height'],
                               width=pic.meta['width'],
                               count=pic.meta['count'],
                               crs=pic.meta['crs'],
                               transform=pic.meta['transform'])
        band =pic.read(2)
        band = inpaintImg(band)
        new_dataset.write(band, 2)
        new_dataset.close()
    return
#writeCleanData(s5p_order)

# %%
s5p_order_c = s5p_order
for i, [date, name] in enumerate(s5p_order_c):
    s5p_order_c[i] = [date, name.replace("s5p_no2", "cleaned_s5p_no2")]

# %% [markdown]
# ## Visualize NO2 on Puerto Rico

# %%
def loadValid(lst):
    for i, row in enumerate(lst):
        image= rio.open(row[1])
        yield(image)
def loadDiff(lst):
    for i, row in enumerate(lst):
        if i!=0:
            image1= rio.open(lst[i-1][1])
            image2= rio.open(lst[i][1])
            img=image2.read(2)-image1.read(2)
            yield(img)

s5p_clean_loader = loadValid(s5p_order_c)
#s5p_inorder_diff = loadDiff(s5p_order)

# %%
import math
#m = 0.00019466211961116649
#m=8.78659099e-05
mx=0
mn = 100000

lag=7
c=0
temp_frames = []
artifactlist = ["eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180927T165725_20181003T182739.tif",
                "eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180828T162223_20180903T175125.tif",
                "eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180822T163536_20180828T180827.tif",
                "eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180719T171554_20180725T185631.tif"]

for frame in s5p_clean_loader:
    bd = frame.read(2)
    if frame.name in artifactlist:
        print("continues")
        continue
    if c < lag:
        temp_frames.append(bd)
        c+=1
    else:
        temp_frames = temp_frames[1:]
        temp_frames.append(bd)
        avg_bd = np.average(temp_frames, axis=0)
        mn = min(mn, np.min(avg_bd))
        mx = max(mx, np.max(avg_bd))

# %%
print("min:", mn)
print("max:", mx)
# Out:
# min: 0.0
# max: 6.750725398368169e-05

# %%
import selenium.webdriver

driver = selenium.webdriver.PhantomJS()
driver.set_window_size(950, 380)  # choose a resolution

lag=7
c=0
temp_frames = []
artifactlist = ["eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180927T165725_20181003T182739.tif",
                "eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180828T162223_20180903T175125.tif",
                "eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180822T163536_20180828T180827.tif",
                "eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180719T171554_20180725T185631.tif"]

s5p_clean_loader = loadValid(s5p_order_c)
for frame in s5p_clean_loader:
    band = frame.read(2)
    if frame.name in artifactlist:
        print("continues")
        continue
    if c < lag:
        temp_frames.append(band)
        c+=1
    else:
        print(frame.name)
        temp_frames = temp_frames[1:]
        temp_frames.append(band)
        temp_frames_np = np.array(temp_frames)
        avg_band = np.average(temp_frames_np, axis=0)
        m = overlay_image_on_puerto_rico(avg_band, cmap=cmap.to_rgba)
        m.save('temp_map.html')
        driver.get('temp_map.html')
        p= "./eie_data/cleaned_s5p_no2_overlays2/"
        driver.save_screenshot(p + frame.name.split("\\")[-1][:-4] + '.png')
        print(frame.name.split("\\")[-1][:-4])
# Out:
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180710T164430_20180716T182411.tif
# cleaned_s5p_no2_20180710T164430_20180716T182411
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180711T162527_20180718T185658.tif
# cleaned_s5p_no2_20180711T162527_20180718T185658
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180712T160623_20180719T105633.tif
# cleaned_s5p_no2_20180712T160623_20180719T105633
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180713T172849_20180719T201407.tif
# cleaned_s5p_no2_20180713T172849_20180719T201407
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180714T170945_20180720T185244.tif
# cleaned_s5p_no2_20180714T170945_20180720T185244
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180715T165041_20180721T182929.tif
# cleaned_s5p_no2_20180715T165041_20180721T182929
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180716T163137_20180722T180949.tif
# cleaned_s5p_no2_20180716T163137_20180722T180949
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180717T161233_20180723T175248.tif
# cleaned_s5p_no2_20180717T161233_20180723T175248
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180718T173458_20180724T193016.tif
# cleaned_s5p_no2_20180718T173458_20180724T193016
# continues
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180720T165649_20180726T182222.tif
# cleaned_s5p_no2_20180720T165649_20180726T182222
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180721T163745_20180727T180656.tif
# cleaned_s5p_no2_20180721T163745_20180727T180656
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180722T161840_20180728T175208.tif
# cleaned_s5p_no2_20180722T161840_20180728T175208
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180723T174105_20180729T195219.tif
# cleaned_s5p_no2_20180723T174105_20180729T195219
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180724T172200_20180730T190909.tif
# cleaned_s5p_no2_20180724T172200_20180730T190909
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180725T170255_20180731T190613.tif
# cleaned_s5p_no2_20180725T170255_20180731T190613
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180726T164350_20180801T182340.tif
# cleaned_s5p_no2_20180726T164350_20180801T182340
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180727T162445_20180803T110400.tif
# cleaned_s5p_no2_20180727T162445_20180803T110400
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180728T160540_20180803T194754.tif
# cleaned_s5p_no2_20180728T160540_20180803T194754
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180729T172805_20180804T185352.tif
# cleaned_s5p_no2_20180729T172805_20180804T185352
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180730T170859_20180805T184831.tif
# cleaned_s5p_no2_20180730T170859_20180805T184831
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180801T163048_20180808T115045.tif
# cleaned_s5p_no2_20180801T163048_20180808T115045
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180802T161143_20180808T214038.tif
# cleaned_s5p_no2_20180802T161143_20180808T214038
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180803T173407_20180809T190038.tif
# cleaned_s5p_no2_20180803T173407_20180809T190038
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180806T163650_20180812T180138.tif
# cleaned_s5p_no2_20180806T163650_20180812T180138
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180807T161744_20180813T174606.tif
# cleaned_s5p_no2_20180807T161744_20180813T174606
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180808T174007_20180814T193039.tif
# cleaned_s5p_no2_20180808T174007_20180814T193039
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180810T170155_20180816T184817.tif
# cleaned_s5p_no2_20180810T170155_20180816T184817
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180812T162343_20180818T180856.tif
# cleaned_s5p_no2_20180812T162343_20180818T180856
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180813T160436_20180819T173731.tif
# cleaned_s5p_no2_20180813T160436_20180819T173731
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180816T164847_20180822T182145.tif
# cleaned_s5p_no2_20180816T164847_20180822T182145
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180817T162940_20180823T180905.tif
# cleaned_s5p_no2_20180817T162940_20180823T180905
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180818T161034_20180824T180018.tif
# cleaned_s5p_no2_20180818T161034_20180824T180018
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180819T173256_20180825T191144.tif
# cleaned_s5p_no2_20180819T173256_20180825T191144
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180820T171350_20180826T185101.tif
# cleaned_s5p_no2_20180820T171350_20180826T185101
# continues
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180823T161629_20180829T180421.tif
# cleaned_s5p_no2_20180823T161629_20180829T180421
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180825T171945_20180831T190726.tif
# cleaned_s5p_no2_20180825T171945_20180831T190726
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180826T170038_20180901T184224.tif
# cleaned_s5p_no2_20180826T170038_20180901T184224
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180827T164130_20180902T182811.tif
# cleaned_s5p_no2_20180827T164130_20180902T182811
# continues
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180830T172538_20180905T191515.tif
# cleaned_s5p_no2_20180830T172538_20180905T191515
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180901T164724_20180907T182554.tif
# cleaned_s5p_no2_20180901T164724_20180907T182554
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180902T162816_20180909T092857.tif
# cleaned_s5p_no2_20180902T162816_20180909T092857
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180903T160909_20180909T180255.tif
# cleaned_s5p_no2_20180903T160909_20180909T180255
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180905T171223_20180911T210517.tif
# cleaned_s5p_no2_20180905T171223_20180911T210517
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180906T165315_20180914T112703.tif
# cleaned_s5p_no2_20180906T165315_20180914T112703
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180907T163408_20180914T095011.tif
# cleaned_s5p_no2_20180907T163408_20180914T095011
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180908T161500_20180914T180515.tif
# cleaned_s5p_no2_20180908T161500_20180914T180515
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180909T173722_20180915T192043.tif
# cleaned_s5p_no2_20180909T173722_20180915T192043
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180910T171814_20180916T185312.tif
# cleaned_s5p_no2_20180910T171814_20180916T185312
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180911T165906_20180917T184020.tif
# cleaned_s5p_no2_20180911T165906_20180917T184020
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180912T163958_20180918T181405.tif
# cleaned_s5p_no2_20180912T163958_20180918T181405
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180913T162050_20180919T174717.tif
# cleaned_s5p_no2_20180913T162050_20180919T174717
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180914T160143_20180920T172815.tif
# cleaned_s5p_no2_20180914T160143_20180920T172815
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180915T172404_20180921T185851.tif
# cleaned_s5p_no2_20180915T172404_20180921T185851
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180916T170456_20180922T184415.tif
# cleaned_s5p_no2_20180916T170456_20180922T184415
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180917T164548_20180923T182508.tif
# cleaned_s5p_no2_20180917T164548_20180923T182508
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180918T162640_20180924T180448.tif
# cleaned_s5p_no2_20180918T162640_20180924T180448
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180919T160732_20180925T174556.tif
# cleaned_s5p_no2_20180919T160732_20180925T174556
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180920T172953_20180926T191318.tif
# cleaned_s5p_no2_20180920T172953_20180926T191318
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180921T171045_20180927T185239.tif
# cleaned_s5p_no2_20180921T171045_20180927T185239
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180922T165137_20180928T182928.tif
# cleaned_s5p_no2_20180922T165137_20180928T182928
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180923T163229_20180929T181448.tif
# cleaned_s5p_no2_20180923T163229_20180929T181448
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180924T161320_20180930T174925.tif
# cleaned_s5p_no2_20180924T161320_20180930T174925
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180926T171633_20181002T185643.tif
# cleaned_s5p_no2_20180926T171633_20181002T185643
# continues
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180928T163817_20181004T182329.tif
# cleaned_s5p_no2_20180928T163817_20181004T182329
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20180929T161908_20181005T180852.tif
# cleaned_s5p_no2_20180929T161908_20181005T180852
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181002T170315_20181008T184359.tif
# cleaned_s5p_no2_20181002T170315_20181008T184359
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181003T164407_20181009T182136.tif
# cleaned_s5p_no2_20181003T164407_20181009T182136
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181004T162458_20181010T175419.tif
# cleaned_s5p_no2_20181004T162458_20181010T175419
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181005T160549_20181011T173641.tif
# cleaned_s5p_no2_20181005T160549_20181011T173641
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181007T170902_20181013T190248.tif
# cleaned_s5p_no2_20181007T170902_20181013T190248
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181008T164953_20181014T182600.tif
# cleaned_s5p_no2_20181008T164953_20181014T182600
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181009T163045_20181015T181045.tif
# cleaned_s5p_no2_20181009T163045_20181015T181045
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181010T161136_20181016T180346.tif
# cleaned_s5p_no2_20181010T161136_20181016T180346
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181012T171449_20181018T185256.tif
# cleaned_s5p_no2_20181012T171449_20181018T185256
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181013T165540_20181019T183046.tif
# cleaned_s5p_no2_20181013T165540_20181019T183046
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181014T163632_20181020T181710.tif
# cleaned_s5p_no2_20181014T163632_20181020T181710
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181017T172036_20181024T140537.tif
# cleaned_s5p_no2_20181017T172036_20181024T140537
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181018T170127_20181024T233406.tif
# cleaned_s5p_no2_20181018T170127_20181024T233406
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181019T164219_20181025T182132.tif
# cleaned_s5p_no2_20181019T164219_20181025T182132
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181020T162310_20181026T180902.tif
# cleaned_s5p_no2_20181020T162310_20181026T180902
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181021T160402_20181027T174638.tif
# cleaned_s5p_no2_20181021T160402_20181027T174638
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181022T172623_20181028T192639.tif
# cleaned_s5p_no2_20181022T172623_20181028T192639
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181023T170715_20181029T190348.tif
# cleaned_s5p_no2_20181023T170715_20181029T190348
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181024T164807_20181030T183236.tif
# cleaned_s5p_no2_20181024T164807_20181030T183236
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181025T162858_20181031T181828.tif
# cleaned_s5p_no2_20181025T162858_20181031T181828
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181026T160950_20181101T175541.tif
# cleaned_s5p_no2_20181026T160950_20181101T175541
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181027T173212_20181102T191944.tif
# cleaned_s5p_no2_20181027T173212_20181102T191944
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181028T171304_20181103T185639.tif
# cleaned_s5p_no2_20181028T171304_20181103T185639
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181029T165356_20181104T184128.tif
# cleaned_s5p_no2_20181029T165356_20181104T184128
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181101T155632_20181107T173227.tif
# cleaned_s5p_no2_20181101T155632_20181107T173227
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181103T165946_20181109T183427.tif
# cleaned_s5p_no2_20181103T165946_20181109T183427
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181104T164039_20181110T181538.tif
# cleaned_s5p_no2_20181104T164039_20181110T181538
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181106T160224_20181112T173321.tif
# cleaned_s5p_no2_20181106T160224_20181112T173321
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181108T170539_20181114T185430.tif
# cleaned_s5p_no2_20181108T170539_20181114T185430
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181109T164632_20181115T181802.tif
# cleaned_s5p_no2_20181109T164632_20181115T181802
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181110T162724_20181116T180345.tif
# cleaned_s5p_no2_20181110T162724_20181116T180345
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181111T160817_20181117T180512.tif
# cleaned_s5p_no2_20181111T160817_20181117T180512
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181112T173040_20181118T191927.tif
# cleaned_s5p_no2_20181112T173040_20181118T191927
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181113T171133_20181119T190628.tif
# cleaned_s5p_no2_20181113T171133_20181119T190628
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181114T165227_20181120T184431.tif
# cleaned_s5p_no2_20181114T165227_20181120T184431
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181115T163320_20181123T135348.tif
# cleaned_s5p_no2_20181115T163320_20181123T135348
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181116T161413_20181122T175640.tif
# cleaned_s5p_no2_20181116T161413_20181122T175640
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181117T155507_20181123T172730.tif
# cleaned_s5p_no2_20181117T155507_20181123T172730
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181118T171730_20181124T185128.tif
# cleaned_s5p_no2_20181118T171730_20181124T185128
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181119T165824_20181125T185246.tif
# cleaned_s5p_no2_20181119T165824_20181125T185246
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181120T163918_20181126T183417.tif
# cleaned_s5p_no2_20181120T163918_20181126T183417
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181121T162012_20181127T180322.tif
# cleaned_s5p_no2_20181121T162012_20181127T180322
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181122T160106_20181128T174046.tif
# cleaned_s5p_no2_20181122T160106_20181128T174046
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181123T172330_20181129T190034.tif
# cleaned_s5p_no2_20181123T172330_20181129T190034
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181124T170424_20181130T185805.tif
# cleaned_s5p_no2_20181124T170424_20181130T185805
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181125T164519_20181201T182531.tif
# cleaned_s5p_no2_20181125T164519_20181201T182531
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181126T162614_20181202T175647.tif
# cleaned_s5p_no2_20181126T162614_20181202T175647
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181127T160708_20181203T173605.tif
# cleaned_s5p_no2_20181127T160708_20181203T173605
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181128T172933_20181205T131600.tif
# cleaned_s5p_no2_20181128T172933_20181205T131600
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181129T171028_20181205T185243.tif
# cleaned_s5p_no2_20181129T171028_20181205T185243
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181201T163218_20181207T181015.tif
# cleaned_s5p_no2_20181201T163218_20181207T181015
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181202T161314_20181208T174454.tif
# cleaned_s5p_no2_20181202T161314_20181208T174454
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181203T155409_20181209T172936.tif
# cleaned_s5p_no2_20181203T155409_20181209T172936
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181204T171635_20181210T190606.tif
# cleaned_s5p_no2_20181204T171635_20181210T190606
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181205T165730_20181211T185709.tif
# cleaned_s5p_no2_20181205T165730_20181211T185709
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181206T163826_20181212T182354.tif
# cleaned_s5p_no2_20181206T163826_20181212T182354
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181207T161922_20181213T180448.tif
# cleaned_s5p_no2_20181207T161922_20181213T180448
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181208T160019_20181214T175916.tif
# cleaned_s5p_no2_20181208T160019_20181214T175916
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181209T172245_20181217T095511.tif
# cleaned_s5p_no2_20181209T172245_20181217T095511
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181211T164438_20181217T230253.tif
# cleaned_s5p_no2_20181211T164438_20181217T230253
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181212T162535_20181218T182010.tif
# cleaned_s5p_no2_20181212T162535_20181218T182010
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181213T160632_20181219T180745.tif
# cleaned_s5p_no2_20181213T160632_20181219T180745
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181214T172858_20181220T193729.tif
# cleaned_s5p_no2_20181214T172858_20181220T193729
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181215T170956_20181221T190658.tif
# cleaned_s5p_no2_20181215T170956_20181221T190658
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181216T165053_20181222T184330.tif
# cleaned_s5p_no2_20181216T165053_20181222T184330
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181217T163150_20181223T181526.tif
# cleaned_s5p_no2_20181217T163150_20181223T181526
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181218T161248_20181224T175044.tif
# cleaned_s5p_no2_20181218T161248_20181224T175044
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181219T155346_20181225T174359.tif
# cleaned_s5p_no2_20181219T155346_20181225T174359
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181220T171613_20181226T185719.tif
# cleaned_s5p_no2_20181220T171613_20181226T185719
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181221T165711_20181227T200848.tif
# cleaned_s5p_no2_20181221T165711_20181227T200848
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181222T163810_20181228T183816.tif
# cleaned_s5p_no2_20181222T163810_20181228T183816
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181223T161908_20181229T180417.tif
# cleaned_s5p_no2_20181223T161908_20181229T180417
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181224T160006_20181230T174413.tif
# cleaned_s5p_no2_20181224T160006_20181230T174413
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181225T172235_20181231T193908.tif
# cleaned_s5p_no2_20181225T172235_20181231T193908
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181226T170334_20190101T185847.tif
# cleaned_s5p_no2_20181226T170334_20190101T185847
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181227T164432_20190102T183936.tif
# cleaned_s5p_no2_20181227T164432_20190102T183936
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181228T162531_20190103T182117.tif
# cleaned_s5p_no2_20181228T162531_20190103T182117
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181229T160630_20190104T181035.tif
# cleaned_s5p_no2_20181229T160630_20190104T181035
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20181230T172900_20190105T192831.tif
# cleaned_s5p_no2_20181230T172900_20190105T192831
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190101T165059_20190107T185757.tif
# cleaned_s5p_no2_20190101T165059_20190107T185757
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190102T163158_20190108T183154.tif
# cleaned_s5p_no2_20190102T163158_20190108T183154
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190103T161258_20190109T181004.tif
# cleaned_s5p_no2_20190103T161258_20190109T181004
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190104T155358_20190110T173454.tif
# cleaned_s5p_no2_20190104T155358_20190110T173454
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190105T171628_20190111T192803.tif
# cleaned_s5p_no2_20190105T171628_20190111T192803
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190107T163828_20190113T182723.tif
# cleaned_s5p_no2_20190107T163828_20190113T182723
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190108T161929_20190114T180349.tif
# cleaned_s5p_no2_20190108T161929_20190114T180349
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190109T160029_20190115T174510.tif
# cleaned_s5p_no2_20190109T160029_20190115T174510
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190110T172300_20190116T193017.tif
# cleaned_s5p_no2_20190110T172300_20190116T193017
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190111T170401_20190117T191336.tif
# cleaned_s5p_no2_20190111T170401_20190117T191336
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190112T164502_20190118T184007.tif
# cleaned_s5p_no2_20190112T164502_20190118T184007
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190113T162603_20190119T180905.tif
# cleaned_s5p_no2_20190113T162603_20190119T180905
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190114T160704_20190120T173725.tif
# cleaned_s5p_no2_20190114T160704_20190120T173725
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190115T172935_20190121T194125.tif
# cleaned_s5p_no2_20190115T172935_20190121T194125
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190116T171037_20190123T104808.tif
# cleaned_s5p_no2_20190116T171037_20190123T104808
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190117T165138_20190123T185558.tif
# cleaned_s5p_no2_20190117T165138_20190123T185558
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190118T163240_20190124T183944.tif
# cleaned_s5p_no2_20190118T163240_20190124T183944
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190119T161341_20190125T175413.tif
# cleaned_s5p_no2_20190119T161341_20190125T175413
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190120T155443_20190126T173142.tif
# cleaned_s5p_no2_20190120T155443_20190126T173142
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190121T171715_20190127T191156.tif
# cleaned_s5p_no2_20190121T171715_20190127T191156
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190122T165817_20190128T190949.tif
# cleaned_s5p_no2_20190122T165817_20190128T190949
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190123T163919_20190129T184821.tif
# cleaned_s5p_no2_20190123T163919_20190129T184821
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190124T162022_20190130T182515.tif
# cleaned_s5p_no2_20190124T162022_20190130T182515
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190125T160124_20190131T175843.tif
# cleaned_s5p_no2_20190125T160124_20190131T175843
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190126T172357_20190201T192405.tif
# cleaned_s5p_no2_20190126T172357_20190201T192405
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190127T170459_20190202T185712.tif
# cleaned_s5p_no2_20190127T170459_20190202T185712
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190128T164602_20190203T184133.tif
# cleaned_s5p_no2_20190128T164602_20190203T184133
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190129T162704_20190204T181439.tif
# cleaned_s5p_no2_20190129T162704_20190204T181439
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190130T160807_20190205T180152.tif
# cleaned_s5p_no2_20190130T160807_20190205T180152
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190201T171143_20190207T185559.tif
# cleaned_s5p_no2_20190201T171143_20190207T185559
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190202T165246_20190208T185635.tif
# cleaned_s5p_no2_20190202T165246_20190208T185635
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190203T163350_20190209T183011.tif
# cleaned_s5p_no2_20190203T163350_20190209T183011
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190204T161453_20190210T180935.tif
# cleaned_s5p_no2_20190204T161453_20190210T180935
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190205T155556_20190211T174416.tif
# cleaned_s5p_no2_20190205T155556_20190211T174416
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190206T171830_20190212T190232.tif
# cleaned_s5p_no2_20190206T171830_20190212T190232
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190207T165933_20190213T190304.tif
# cleaned_s5p_no2_20190207T165933_20190213T190304
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190208T164037_20190214T182553.tif
# cleaned_s5p_no2_20190208T164037_20190214T182553
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190209T162140_20190215T180733.tif
# cleaned_s5p_no2_20190209T162140_20190215T180733
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190210T160244_20190216T174151.tif
# cleaned_s5p_no2_20190210T160244_20190216T174151
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190211T172518_20190217T193020.tif
# cleaned_s5p_no2_20190211T172518_20190217T193020
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190212T170622_20190218T185812.tif
# cleaned_s5p_no2_20190212T170622_20190218T185812
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190213T164726_20190219T184156.tif
# cleaned_s5p_no2_20190213T164726_20190219T184156
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190214T162830_20190220T182009.tif
# cleaned_s5p_no2_20190214T162830_20190220T182009
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190215T160934_20190221T175616.tif
# cleaned_s5p_no2_20190215T160934_20190221T175616
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190216T173208_20190222T194423.tif
# cleaned_s5p_no2_20190216T173208_20190222T194423
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190217T171312_20190223T191237.tif
# cleaned_s5p_no2_20190217T171312_20190223T191237
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190218T165417_20190224T185100.tif
# cleaned_s5p_no2_20190218T165417_20190224T185100
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190219T163521_20190225T182309.tif
# cleaned_s5p_no2_20190219T163521_20190225T182309
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190220T161625_20190226T180935.tif
# cleaned_s5p_no2_20190220T161625_20190226T180935
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190221T155730_20190227T174434.tif
# cleaned_s5p_no2_20190221T155730_20190227T174434
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190222T172004_20190228T192830.tif
# cleaned_s5p_no2_20190222T172004_20190228T192830
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190223T170109_20190301T184549.tif
# cleaned_s5p_no2_20190223T170109_20190301T184549
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190224T164213_20190302T182354.tif
# cleaned_s5p_no2_20190224T164213_20190302T182354
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190225T162318_20190303T180302.tif
# cleaned_s5p_no2_20190225T162318_20190303T180302
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190226T160422_20190304T181153.tif
# cleaned_s5p_no2_20190226T160422_20190304T181153
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190227T172657_20190305T192632.tif
# cleaned_s5p_no2_20190227T172657_20190305T192632
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190301T164907_20190307T185348.tif
# cleaned_s5p_no2_20190301T164907_20190307T185348
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190302T163011_20190308T182209.tif
# cleaned_s5p_no2_20190302T163011_20190308T182209
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190303T161116_20190309T180108.tif
# cleaned_s5p_no2_20190303T161116_20190309T180108
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190304T173351_20190310T192126.tif
# cleaned_s5p_no2_20190304T173351_20190310T192126
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190305T171456_20190312T111555.tif
# cleaned_s5p_no2_20190305T171456_20190312T111555
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190306T165601_20190312T201049.tif
# cleaned_s5p_no2_20190306T165601_20190312T201049
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190307T163706_20190313T183909.tif
# cleaned_s5p_no2_20190307T163706_20190313T183909
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190308T161811_20190314T183645.tif
# cleaned_s5p_no2_20190308T161811_20190314T183645
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190309T155916_20190315T173727.tif
# cleaned_s5p_no2_20190309T155916_20190315T173727
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190310T172151_20190316T185510.tif
# cleaned_s5p_no2_20190310T172151_20190316T185510
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190311T170256_20190317T183546.tif
# cleaned_s5p_no2_20190311T170256_20190317T183546
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190312T164401_20190318T183359.tif
# cleaned_s5p_no2_20190312T164401_20190318T183359
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190313T162506_20190319T180821.tif
# cleaned_s5p_no2_20190313T162506_20190319T180821
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190314T160611_20190320T174351.tif
# cleaned_s5p_no2_20190314T160611_20190320T174351
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190315T172846_20190321T191319.tif
# cleaned_s5p_no2_20190315T172846_20190321T191319
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190316T170951_20190322T190733.tif
# cleaned_s5p_no2_20190316T170951_20190322T190733
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190317T165056_20190323T185720.tif
# cleaned_s5p_no2_20190317T165056_20190323T185720
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190318T163201_20190324T182654.tif
# cleaned_s5p_no2_20190318T163201_20190324T182654
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190319T161306_20190325T175658.tif
# cleaned_s5p_no2_20190319T161306_20190325T175658
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190320T173542_20190328T171605.tif
# cleaned_s5p_no2_20190320T173542_20190328T171605
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190321T171647_20190328T175313.tif
# cleaned_s5p_no2_20190321T171647_20190328T175313
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190322T165752_20190329T104138.tif
# cleaned_s5p_no2_20190322T165752_20190329T104138
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190323T163857_20190329T182521.tif
# cleaned_s5p_no2_20190323T163857_20190329T182521
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190324T162002_20190330T175644.tif
# cleaned_s5p_no2_20190324T162002_20190330T175644
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190325T160107_20190331T174305.tif
# cleaned_s5p_no2_20190325T160107_20190331T174305
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190326T172342_20190401T190943.tif
# cleaned_s5p_no2_20190326T172342_20190401T190943
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190327T170447_20190402T184708.tif
# cleaned_s5p_no2_20190327T170447_20190402T184708
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190328T164552_20190403T182232.tif
# cleaned_s5p_no2_20190328T164552_20190403T182232
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190329T162656_20190404T180528.tif
# cleaned_s5p_no2_20190329T162656_20190404T180528
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190330T160801_20190405T173718.tif
# cleaned_s5p_no2_20190330T160801_20190405T173718
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190401T171141_20190407T185548.tif
# cleaned_s5p_no2_20190401T171141_20190407T185548
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190403T163351_20190409T181128.tif
# cleaned_s5p_no2_20190403T163351_20190409T181128
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190404T161456_20190410T175148.tif
# cleaned_s5p_no2_20190404T161456_20190410T175148
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190405T173731_20190411T192549.tif
# cleaned_s5p_no2_20190405T173731_20190411T192549
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190406T171835_20190412T191108.tif
# cleaned_s5p_no2_20190406T171835_20190412T191108
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190407T165940_20190413T184553.tif
# cleaned_s5p_no2_20190407T165940_20190413T184553
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190408T164045_20190414T182005.tif
# cleaned_s5p_no2_20190408T164045_20190414T182005
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190409T162149_20190415T175633.tif
# cleaned_s5p_no2_20190409T162149_20190415T175633
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190410T160254_20190416T174818.tif
# cleaned_s5p_no2_20190410T160254_20190416T174818
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190411T172528_20190418T091559.tif
# cleaned_s5p_no2_20190411T172528_20190418T091559
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190412T170633_20190418T190433.tif
# cleaned_s5p_no2_20190412T170633_20190418T190433
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190413T164737_20190419T183141.tif
# cleaned_s5p_no2_20190413T164737_20190419T183141
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190414T162841_20190420T181353.tif
# cleaned_s5p_no2_20190414T162841_20190420T181353
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190415T160945_20190421T174932.tif
# cleaned_s5p_no2_20190415T160945_20190421T174932
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190416T173220_20190422T191520.tif
# cleaned_s5p_no2_20190416T173220_20190422T191520
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190417T171324_20190423T185147.tif
# cleaned_s5p_no2_20190417T171324_20190423T185147
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190418T165428_20190424T183227.tif
# cleaned_s5p_no2_20190418T165428_20190424T183227
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190419T163532_20190425T183605.tif
# cleaned_s5p_no2_20190419T163532_20190425T183605
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190420T161636_20190426T180202.tif
# cleaned_s5p_no2_20190420T161636_20190426T180202
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190421T173910_20190427T192626.tif
# cleaned_s5p_no2_20190421T173910_20190427T192626
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190422T172014_20190428T191552.tif
# cleaned_s5p_no2_20190422T172014_20190428T191552
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190423T170118_20190501T100210.tif
# cleaned_s5p_no2_20190423T170118_20190501T100210
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190424T164221_20190501T013253.tif
# cleaned_s5p_no2_20190424T164221_20190501T013253
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190425T162325_20190501T182258.tif
# cleaned_s5p_no2_20190425T162325_20190501T182258
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190426T160428_20190502T180735.tif
# cleaned_s5p_no2_20190426T160428_20190502T180735
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190427T172702_20190503T191754.tif
# cleaned_s5p_no2_20190427T172702_20190503T191754
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190428T170805_20190504T190135.tif
# cleaned_s5p_no2_20190428T170805_20190504T190135
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190429T164908_20190505T183330.tif
# cleaned_s5p_no2_20190429T164908_20190505T183330
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190501T161114_20190507T174400.tif
# cleaned_s5p_no2_20190501T161114_20190507T174400
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190502T173348_20190508T192249.tif
# cleaned_s5p_no2_20190502T173348_20190508T192249
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190503T171451_20190509T185524.tif
# cleaned_s5p_no2_20190503T171451_20190509T185524
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190504T165553_20190510T183608.tif
# cleaned_s5p_no2_20190504T165553_20190510T183608
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190505T163656_20190511T181623.tif
# cleaned_s5p_no2_20190505T163656_20190511T181623
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190506T161759_20190512T180440.tif
# cleaned_s5p_no2_20190506T161759_20190512T180440
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190507T174031_20190513T193635.tif
# cleaned_s5p_no2_20190507T174031_20190513T193635
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190508T172134_20190514T192623.tif
# cleaned_s5p_no2_20190508T172134_20190514T192623
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190509T170236_20190515T190123.tif
# cleaned_s5p_no2_20190509T170236_20190515T190123
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190510T164338_20190516T183223.tif
# cleaned_s5p_no2_20190510T164338_20190516T183223
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190511T162440_20190517T185214.tif
# cleaned_s5p_no2_20190511T162440_20190517T185214
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190512T160542_20190518T174834.tif
# cleaned_s5p_no2_20190512T160542_20190518T174834
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190513T172814_20190519T194051.tif
# cleaned_s5p_no2_20190513T172814_20190519T194051
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190514T170916_20190522T123514.tif
# cleaned_s5p_no2_20190514T170916_20190522T123514
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190515T165018_20190522T134222.tif
# cleaned_s5p_no2_20190515T165018_20190522T134222
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190516T163119_20190522T193957.tif
# cleaned_s5p_no2_20190516T163119_20190522T193957
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190517T161221_20190523T180728.tif
# cleaned_s5p_no2_20190517T161221_20190523T180728
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190518T173452_20190524T194317.tif
# cleaned_s5p_no2_20190518T173452_20190524T194317
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190519T171554_20190525T191440.tif
# cleaned_s5p_no2_20190519T171554_20190525T191440
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190520T165655_20190526T184918.tif
# cleaned_s5p_no2_20190520T165655_20190526T184918
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190521T163756_20190527T183309.tif
# cleaned_s5p_no2_20190521T163756_20190527T183309
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190522T161857_20190528T182426.tif
# cleaned_s5p_no2_20190522T161857_20190528T182426
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190523T174128_20190529T194248.tif
# cleaned_s5p_no2_20190523T174128_20190529T194248
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190524T172228_20190530T190715.tif
# cleaned_s5p_no2_20190524T172228_20190530T190715
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190525T170329_20190531T184545.tif
# cleaned_s5p_no2_20190525T170329_20190531T184545
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190526T164429_20190601T183339.tif
# cleaned_s5p_no2_20190526T164429_20190601T183339
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190528T160630_20190603T180628.tif
# cleaned_s5p_no2_20190528T160630_20190603T180628
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190529T172900_20190604T193536.tif
# cleaned_s5p_no2_20190529T172900_20190604T193536
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190530T171000_20190605T185656.tif
# cleaned_s5p_no2_20190530T171000_20190605T185656
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190601T163159_20190607T183826.tif
# cleaned_s5p_no2_20190601T163159_20190607T183826
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190602T161259_20190608T180324.tif
# cleaned_s5p_no2_20190602T161259_20190608T180324
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190603T173529_20190609T192940.tif
# cleaned_s5p_no2_20190603T173529_20190609T192940
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190604T171628_20190610T190555.tif
# cleaned_s5p_no2_20190604T171628_20190610T190555
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190606T163826_20190612T182811.tif
# cleaned_s5p_no2_20190606T163826_20190612T182811
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190607T161925_20190613T175313.tif
# cleaned_s5p_no2_20190607T161925_20190613T175313
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190609T172253_20190615T221136.tif
# cleaned_s5p_no2_20190609T172253_20190615T221136
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190610T170352_20190616T184220.tif
# cleaned_s5p_no2_20190610T170352_20190616T184220
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190611T164450_20190617T182405.tif
# cleaned_s5p_no2_20190611T164450_20190617T182405
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190612T162549_20190618T180057.tif
# cleaned_s5p_no2_20190612T162549_20190618T180057
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190613T160647_20190619T174418.tif
# cleaned_s5p_no2_20190613T160647_20190619T174418
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190614T172915_20190620T191204.tif
# cleaned_s5p_no2_20190614T172915_20190620T191204
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190615T171013_20190621T185440.tif
# cleaned_s5p_no2_20190615T171013_20190621T185440
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190616T165111_20190622T183247.tif
# cleaned_s5p_no2_20190616T165111_20190622T183247
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190617T163209_20190623T182116.tif
# cleaned_s5p_no2_20190617T163209_20190623T182116
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190618T161307_20190624T180620.tif
# cleaned_s5p_no2_20190618T161307_20190624T180620
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190619T173534_20190625T192848.tif
# cleaned_s5p_no2_20190619T173534_20190625T192848
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190620T171632_20190626T190833.tif
# cleaned_s5p_no2_20190620T171632_20190626T190833
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190621T165729_20190627T185343.tif
# cleaned_s5p_no2_20190621T165729_20190627T185343
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190622T163826_20190628T181049.tif
# cleaned_s5p_no2_20190622T163826_20190628T181049
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190623T161923_20190629T180700.tif
# cleaned_s5p_no2_20190623T161923_20190629T180700
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190624T174150_20190630T192108.tif
# cleaned_s5p_no2_20190624T174150_20190630T192108
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190626T170344_20190703T114437.tif
# cleaned_s5p_no2_20190626T170344_20190703T114437
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190627T164441_20190703T183146.tif
# cleaned_s5p_no2_20190627T164441_20190703T183146
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190628T162537_20190704T180917.tif
# cleaned_s5p_no2_20190628T162537_20190704T180917
# eie_data\cleaned_s5p_no2\cleaned_s5p_no2_20190629T160634_20190705T174521.tif
# cleaned_s5p_no2_20190629T160634_20190705T174521

# %%
import os
def readOverlay(p="./eie_data/cleaned_s5p_no2_overlays/"):
    images = []
    for filename in os.listdir(p):
        img = cv.imread(os.path.join(p,filename))
        if img is not None:
            images.append(img)
    np_im_lst = np.array(images)
    return(np_im_lst)
overlay_loader = readOverlay()
overlay_loader2 = readOverlay(p="./eie_data/cleaned_s5p_no2_overlays2/")

# %% [markdown]
# ## Show overlay film

# %%
def showOverlayFilm(loader):
    # %matplotlib tk
    fig, ax = plt.subplots(1,1)
    for frame in loader:
        ax.cla()
        ax.imshow(frame)
        plt.pause(0.2)
    plt.close()
    # %matplotlib inline
    return

# %%
showOverlayFilm(overlay_loader)

# %%
showOverlayFilm(overlay_loader2)

# %%
# write as mp4:
import imageio
imageio.mimwrite('NO2_concentration_20180710T20190629.mp4', overlay_loader2 , fps = 5)
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (950, 380) to (960, 384) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).

# %% [markdown]
# ## Extra stuff
